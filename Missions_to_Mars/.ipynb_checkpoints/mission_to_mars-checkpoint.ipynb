# %%
# Import dependancies
from bs4 import BeautifulSoup
import requests
import pymongo
from selenium import webdriver
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

# %%
##############################
# Featured Mars Article
##############################

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Driver [C:\Users\jerom\.wdm\drivers\chromedriver\win32\93.0.4577.63\chromedriver.exe] found in cache

# %%
# URL for Mars News page
url = "https://redplanetscience.com/#"

# %%
# Visit Mars News page in browser, wait for all content to generate
browser.visit(url)
time.sleep(3)
html = browser.html

# %%
# Create BS object and parse it
soup = BeautifulSoup(html, "lxml")

# %%
# Check to see if page is correct
soup.body
# Out:
# <body>
# <div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# <span class="logo1">Exploration Program</span>
# </a>
# <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#navbarNav" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
# <ul class="navbar-nav">
# <li class="nav-item">
# <a aria-current="page" class="nav-link active" href="#">The Red Planet</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">The Program</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">News &amp; Events</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Multimedia</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">Missions</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="#">More</a>
# </li>
# <li class="nav-item nav_search">
# <a class="nav-link" href="#"></a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <section class="search">
# <div class="container">
# <h1>News</h1>
# <div class="col-md-12 filter">
# <div class="row">
# <div class="col-md-3 search_binder">
# <input class="search_field" name="search" type="text"/>
# <input class="search_submit" name="search" type="text"/>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="year">
# <option selected="">Latest</option>
# <option>2020</option><option>2019</option></select>
# </div>
# <div class="col-md-3">
# <select aria-label="Default select example" class="form-select" id="cat">
# <option selected="">All Categories</option>
# <option>Feature Stories</option><option>Press Releases</option><option>Status Reports</option></select>
# </div>
# <div class="col-md-3">
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="image_and_description_container">
# <div class="container" id="news">
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8671_PIA23890-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">September 12, 2021</div>
# <div class="content_title">NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound</div>
# <div class="article_teaser_body">The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8544_Pathfinder-Background-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">September 11, 2021</div>
# <div class="content_title">Screening Soon: 'The Pathfinders' Trains Lens on Mars</div>
# <div class="article_teaser_body">With the Mars 2020 mission ramping up, the documentary — the first of four about past JPL missions to the Red Planet to be shown at Caltech — tells a gripping backstory.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8444_Sol427-437_backcap_push_positioning-320x240.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">September 9, 2021</div>
# <div class="content_title">Common Questions about InSight's 'Mole'</div>
# <div class="article_teaser_body">The following Q&amp;As with members of the team answer some of the most common questions about the burrowing device, part of a science instrument called the Heat Flow and Physical Properties Package (HP3).</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8710_MARS2020_LAUNCH_320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">September 8, 2021</div>
# <div class="content_title">Join NASA for the Launch of the Mars 2020 Perseverance Rover</div>
# <div class="article_teaser_body">No matter where you live, choose from a menu of activities to join NASA as we "Countdown to Mars" and launch the Perseverance rover to the Red Planet.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8756_25254_Christina_hernandez_mainmax-320x240.png"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">September 7, 2021</div>
# <div class="content_title">My Culture, My Voice</div>
# <div class="article_teaser_body">In honor of Hispanic Heritage Month, Christina Hernandez, an instrument engineer on the Mars 2020 mission, talks about her childhood and journey to NASA.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8817_PIA23180_320.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">September 4, 2021</div>
# <div class="content_title">3 Things We've Learned From NASA's Mars InSight </div>
# <div class="article_teaser_body">Scientists are finding new mysteries since the geophysics mission landed two years ago.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8506_mars-solar-conjunction-th.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">September 4, 2021</div>
# <div class="content_title">What's Mars Solar Conjunction, and Why Does It Matter?</div>
# <div class="article_teaser_body">NASA spacecraft at Mars are going to be on their own for a few weeks when the Sun comes between Mars and Earth, interrupting communications.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8721_24759_PIA23491-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">August 31, 2021</div>
# <div class="content_title">A New Video Captures the Science of NASA's Perseverance Mars Rover</div>
# <div class="article_teaser_body">With a targeted launch date of July 30, the next robotic scientist NASA is sending to the to the Red Planet has big ambitions.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8695_24732_PIA23499-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">August 29, 2021</div>
# <div class="content_title">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</div>
# <div class="article_teaser_body">The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8682_SCS-16-MAIN-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">August 21, 2021</div>
# <div class="content_title">The Extraordinary Sample-Gathering System of NASA's Perseverance Mars Rover</div>
# <div class="article_teaser_body">Two astronauts collected Moon rocks on Apollo 11. It will take three robotic systems working together to gather up the first Mars rock samples for return to Earth.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8408_22206_PIA22655-th.gif"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">August 21, 2021</div>
# <div class="content_title">The MarCO Mission Comes to an End</div>
# <div class="article_teaser_body">The pair of briefcase-sized satellites made history when they sailed past Mars in 2019.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8680_mavenmarselectriccurrents-320x240.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">August 20, 2021</div>
# <div class="content_title">MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss</div>
# <div class="article_teaser_body">Five years after NASA’s MAVEN spacecraft entered into orbit around Mars, data from the mission has led to the creation of a map of electric current systems in the Martian atmosphere.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8705_PIA23896-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">August 19, 2021</div>
# <div class="content_title">NASA's InSight Flexes Its Arm While Its 'Mole' Hits Pause</div>
# <div class="article_teaser_body">Now that the lander's robotic arm has helped the mole get underground, it will resume science activities that have been on hold.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8639_bob-heli-226.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">August 16, 2021</div>
# <div class="content_title">The Man Who Wanted to Fly on Mars</div>
# <div class="article_teaser_body">The Mars Helicopter is riding to the Red Planet this summer with NASA's Perseverance rover. The helicopter's chief engineer, Bob Balaram, shares the saga of how it came into being.</div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-md-12">
# <hr/>
# <div class="row">
# <div class="col-md-4">
# <div class="list_image">
# <img src="https://mars.nasa.gov/system/news_items/list_view_images/8815_C1-bill-allen-Mars-Yard-2020-320.jpg"/>
# </div>
# </div>
# <div class="col-md-8">
# <div class="list_text">
# <div class="list_date">August 13, 2021</div>
# <div class="content_title">From JPL's Mailroom to Mars and Beyond</div>
# <div class="article_teaser_body">Bill Allen has thrived as the mechanical systems design lead for three Mars rover missions, but he got his start as a teenager sorting letters for the NASA center.</div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <hr class="container" style="margin: 25px auto;width: 83%;"/>
# <button class="btn disable" id="more" onclick="populateContent()">More</button>
# </section>
# <section class="last_news">
# <div class="container">
# <div class="row">
# <div class="col-12">
# <h2>You Might Also Like</h2>
# </div>
# <!--  <a class=" prev" href="#carouselExampleIndicators2" role="button" data-slide="prev">
#                   <i class="fas fa-angle-left"></i>
#                   </a>
#                   <a class=" next" href="#carouselExampleIndicators2" role="button" data-slide="next">
#                   <i class="fas fa-angle-right"></i>
#                   </a> -->
# <div class="col-12">
# <div class="carousel slide" data-ride="carousel" id="carouselExampleIndicators2">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Broadcast Mars 2020 Perseverance Launch, Prelaunch Activities</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8716_PIA23499-16.jpg"/>
# <div class="card-body">
# <p class="card-text">The Launch Is Approaching for NASA's Next Mars Rover, Perseverance</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://mars.nasa.gov/system/news_items/main_images/8692_PIA23920-web.jpg"/>
# <div class="card-body">
# <p class="card-text">NASA to Hold Mars 2020 Perseverance Rover Launch Briefing</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532771098148-525cefe10c23?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=3f317c1f7a16116dec454fbc267dd8e4"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532715088550-62f09305f765?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ebadb044b374504ef8e81bdec4d0e840"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1506197603052-3cc9c3a201bd?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=0754ab085804ae8a3b562548e6b4aa2e"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="carousel-item">
# <div class="row">
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1507525428034-b723cf961d3e?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=ee8417f0ea2a50d53a12665820b54e23"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532777946373-b6783242f211?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=8ac55cf3a68785643998730839663129"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# <div class="col-md-4 mb-3">
# <div class="card">
# <img alt="100%x280" class="img-fluid" src="https://images.unsplash.com/photo-1532763303805-529d595877c5?ixlib=rb-0.3.5&amp;q=80&amp;fm=jpg&amp;crop=entropy&amp;cs=tinysrgb&amp;w=1080&amp;fit=max&amp;ixid=eyJhcHBfaWQiOjMyMDc0fQ&amp;s=5ee4fd5d19b40f93eadb21871757eda6"/>
# <div class="card-body">
# <p class="card-text">With supporting text below as a natural lead-in to additional content.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="footer">
# <div class="container">
# <div class="col-md-12">
# <div class="row">
# <div class="col-md-3">
# <h5>The Red Planet</h5>
# <ul>
# <li>Dashboard</li>
# <li>Science Goals</li>
# <li>The Planet</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>The Program</h5>
# <ul>
# <li>Mission Statement</li>
# <li>About the Program</li>
# <li>Organization Why Mars?</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Multimedia</h5>
# <ul>
# <li>Images</li>
# <li>Videos</li>
# <li>More Resources</li>
# </ul>
# </div>
# <div class="col-md-3">
# <h5>Missions</h5>
# <ul>
# <li>Past</li>
# <li>Present</li>
# <li>Future</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <script src="https://code.jquery.com/jquery-1.12.4.min.js" type="text/javascript"></script>
# <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.5.4/dist/umd/popper.min.js"></script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/js/bootstrap.min.js"></script>
# <script src="js/app.js"></script>
# </div></div></body>

# %%
# Get most recent article title
content_title = soup.find('div', class_='content_title').text
content_title
# Out:
# "NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound"

# %%
# Get most recent article teaser text
content_teaser = soup.find('div', class_='article_teaser_body').text
content_teaser
# Out:
# "The agency's new Mars rover is put through a series of tests in vacuum chambers, acoustic chambers and more to get ready for the Red Planet."

# %%
##############################
# Featured Mars Image
##############################

# %%
# Mars Images URL
url2 = "https://spaceimages-mars.com/"

# %%
# Visit Mars Images page in browser, wait for content to generate
browser.visit(url2)
time.sleep(3)
html2 = browser.html

# %%
# Create BS object and parse it
soup = BeautifulSoup(html2, "lxml")

# %%
# Check to see if page is correct
soup.body()
# Out:
# [<div class="header">
#  <nav class="navbar navbar-expand-lg">
#  <a class="navbar-brand" href="#"><img id="logo" src="image/nasa.png"/><span class="logo">Jet Propulsion Laboratory</span>
#  <span class="logo1">California Institute of Technology</span></a>
#  <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarNav" data-toggle="collapse" type="button">
#  <span class="navbar-toggler-icon"></span>
#  </button>
#  <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#  <ul class="navbar-nav">
#  <li class="nav-item active">
#  <a class="nav-link" href="#"><i aria-hidden="true" class="fa fa-bars"></i>   MENU   <i aria-hidden="true" class="fa fa-search"></i></a>
#  </li>
#  </ul>
#  </div>
#  </nav>
#  <div class="floating_text_area">
#  <h2 class="brand_title">FEATURED IMAGE</h2>
#  <h1 class="media_feature_title">Dusty Space Cloud</h1>
#  <br/>
#  <a class="showimg fancybox-thumbs" href="image/featured/mars2.jpg" target="_blank"> <button class="btn btn-outline-light"> FULL IMAGE</button></a>
#  </div>
#  <img class="headerimage fade-in" src="image/featured/mars2.jpg"/></div>,
#  <nav class="navbar navbar-expand-lg">
#  <a class="navbar-brand" href="#"><img id="logo" src="image/nasa.png"/><span class="logo">Jet Propulsion Laboratory</span>
#  <span class="logo1">California Institute of Technology</span></a>
#  <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarNav" data-toggle="collapse" type="button">
#  <span class="navbar-toggler-icon"></span>
#  </button>
#  <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#  <ul class="navbar-nav">
#  <li class="nav-item active">
#  <a class="nav-link" href="#"><i aria-hidden="true" class="fa fa-bars"></i>   MENU   <i aria-hidden="true" class="fa fa-search"></i></a>
#  </li>
#  </ul>
#  </div>
#  </nav>,
#  <a class="navbar-brand" href="#"><img id="logo" src="image/nasa.png"/><span class="logo">Jet Propulsion Laboratory</span>
#  <span class="logo1">California Institute of Technology</span></a>,
#  <img id="logo" src="image/nasa.png"/>,
#  <span class="logo">Jet Propulsion Laboratory</span>,
#  <span class="logo1">California Institute of Technology</span>,
#  <button aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarNav" data-toggle="collapse" type="button">
#  <span class="navbar-toggler-icon"></span>
#  </button>,
#  <span class="navbar-toggler-icon"></span>,
#  <div class="collapse navbar-collapse justify-content-end" id="navbarNav">
#  <ul class="navbar-nav">
#  <li class="nav-item active">
#  <a class="nav-link" href="#"><i aria-hidden="true" class="fa fa-bars"></i>   MENU   <i aria-hidden="true" class="fa fa-search"></i></a>
#  </li>
#  </ul>
#  </div>,
#  <ul class="navbar-nav">
#  <li class="nav-item active">
#  <a class="nav-link" href="#"><i aria-hidden="true" class="fa fa-bars"></i>   MENU   <i aria-hidden="true" class="fa fa-search"></i></a>
#  </li>
#  </ul>,
#  <li class="nav-item active">
#  <a class="nav-link" href="#"><i aria-hidden="true" class="fa fa-bars"></i>   MENU   <i aria-hidden="true" class="fa fa-search"></i></a>
#  </li>,
#  <a class="nav-link" href="#"><i aria-hidden="true" class="fa fa-bars"></i>   MENU   <i aria-hidden="true" class="fa fa-search"></i></a>,
#  <i aria-hidden="true" class="fa fa-bars"></i>,
#  <i aria-hidden="true" class="fa fa-search"></i>,
#  <div class="floating_text_area">
#  <h2 class="brand_title">FEATURED IMAGE</h2>
#  <h1 class="media_feature_title">Dusty Space Cloud</h1>
#  <br/>
#  <a class="showimg fancybox-thumbs" href="image/featured/mars2.jpg" target="_blank"> <button class="btn btn-outline-light"> FULL IMAGE</button></a>
#  </div>,
#  <h2 class="brand_title">FEATURED IMAGE</h2>,
#  <h1 class="media_feature_title">Dusty Space Cloud</h1>,
#  <br/>,
#  <a class="showimg fancybox-thumbs" href="image/featured/mars2.jpg" target="_blank"> <button class="btn btn-outline-light"> FULL IMAGE</button></a>,
#  <button class="btn btn-outline-light"> FULL IMAGE</button>,
#  <img class="headerimage fade-in" src="image/featured/mars2.jpg"/>,
#  <div class="search sticky">
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-6">
#  <input name="Search" placeholder="Search" type="text"/>
#  </div>
#  <div class="col-md-6">
#  <select aria-label="Default select example" class="form-select" id="options">
#  <option onchange="0" selected="">Mars</option>
#  <!-- <option data-filter="sun" class="button">Mars</option> -->
#  <option class="button" data-filter="Sun">Sun</option>
#  <option class="button" data-filter="earth">Earth</option>
#  <option class="button" data-filter="ida">Ida</option>
#  <option class="button" data-filter="jupiter">Jupiter</option>
#  <option class="button" data-filter="venus">Venus</option>
#  </select>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-6">
#  <input name="Search" placeholder="Search" type="text"/>
#  </div>
#  <div class="col-md-6">
#  <select aria-label="Default select example" class="form-select" id="options">
#  <option onchange="0" selected="">Mars</option>
#  <!-- <option data-filter="sun" class="button">Mars</option> -->
#  <option class="button" data-filter="Sun">Sun</option>
#  <option class="button" data-filter="earth">Earth</option>
#  <option class="button" data-filter="ida">Ida</option>
#  <option class="button" data-filter="jupiter">Jupiter</option>
#  <option class="button" data-filter="venus">Venus</option>
#  </select>
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-6">
#  <input name="Search" placeholder="Search" type="text"/>
#  </div>
#  <div class="col-md-6">
#  <select aria-label="Default select example" class="form-select" id="options">
#  <option onchange="0" selected="">Mars</option>
#  <!-- <option data-filter="sun" class="button">Mars</option> -->
#  <option class="button" data-filter="Sun">Sun</option>
#  <option class="button" data-filter="earth">Earth</option>
#  <option class="button" data-filter="ida">Ida</option>
#  <option class="button" data-filter="jupiter">Jupiter</option>
#  <option class="button" data-filter="venus">Venus</option>
#  </select>
#  </div>
#  </div>,
#  <div class="col-md-6">
#  <input name="Search" placeholder="Search" type="text"/>
#  </div>,
#  <input name="Search" placeholder="Search" type="text"/>,
#  <div class="col-md-6">
#  <select aria-label="Default select example" class="form-select" id="options">
#  <option onchange="0" selected="">Mars</option>
#  <!-- <option data-filter="sun" class="button">Mars</option> -->
#  <option class="button" data-filter="Sun">Sun</option>
#  <option class="button" data-filter="earth">Earth</option>
#  <option class="button" data-filter="ida">Ida</option>
#  <option class="button" data-filter="jupiter">Jupiter</option>
#  <option class="button" data-filter="venus">Venus</option>
#  </select>
#  </div>,
#  <select aria-label="Default select example" class="form-select" id="options">
#  <option onchange="0" selected="">Mars</option>
#  <!-- <option data-filter="sun" class="button">Mars</option> -->
#  <option class="button" data-filter="Sun">Sun</option>
#  <option class="button" data-filter="earth">Earth</option>
#  <option class="button" data-filter="ida">Ida</option>
#  <option class="button" data-filter="jupiter">Jupiter</option>
#  <option class="button" data-filter="venus">Venus</option>
#  </select>,
#  <option onchange="0" selected="">Mars</option>,
#  <option class="button" data-filter="Sun">Sun</option>,
#  <option class="button" data-filter="earth">Earth</option>,
#  <option class="button" data-filter="ida">Ida</option>,
#  <option class="button" data-filter="jupiter">Jupiter</option>,
#  <option class="button" data-filter="venus">Venus</option>,
#  <div class="container mt-5">
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-6">
#  <h1>Images</h1>
#  </div>
#  <div class="col-md-6" id="icon">
#  <div class="icon2"></div>
#  <div class="icon1"></div>
#  </div>
#  </div>
#  </div>
#  <!-- first div -->
#  <div class="div1" id="filter">
#  <div class="thmbgroup"><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">January 1, 2020<br/>Icaria Fossae7</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 31, 2020<br/>Proctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">December 31, 2020<br/>Icaria Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 29, 2020<br/>Proctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 28, 2020<br/>roctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">December 22, 2020<br/>Icaria Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/><p class="thumbcontent">December 21, 2020<br/>Icaria Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">December 18, 2020<br/>Ariadnes Colles</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">December 17, 2020<br/>Niger Vallis</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes.jpg"/><p class="thumbcontent">December 16, 2020<br/>Proctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">December 15, 2020<br/>Niger Vallis</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">December 11, 2020<br/>Daedalia Planum</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Sirenum Fossae.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Sirenum Fossae.jpg"/><p class="thumbcontent">November,11, 2020<br/>Sirenum Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">November,13, 2020<br/>Ariadnes Colles</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/South Polar Cap.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/><p class="thumbcontent">November,14, 2020<br/>South Polar Cap</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg"><div class="thmb"><img alt="" class="thumbimg" src="i ...
#  </div>
#  <!-- first div ends -->
#  <!-- second div starts -->
#  <div class="col-md-12 grid-margin" id="column">
#  <ul class="post-list">
#  <li class="post-heading"></li>
#  </ul>
#  </div>
#  <!-- second div starts -->
#  </div>,
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-6">
#  <h1>Images</h1>
#  </div>
#  <div class="col-md-6" id="icon">
#  <div class="icon2"></div>
#  <div class="icon1"></div>
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-6">
#  <h1>Images</h1>
#  </div>
#  <div class="col-md-6" id="icon">
#  <div class="icon2"></div>
#  <div class="icon1"></div>
#  </div>
#  </div>,
#  <div class="col-md-6">
#  <h1>Images</h1>
#  </div>,
#  <h1>Images</h1>,
#  <div class="col-md-6" id="icon">
#  <div class="icon2"></div>
#  <div class="icon1"></div>
#  </div>,
#  <div class="icon2"></div>,
#  <div class="icon1"></div>,
#  <div class="div1" id="filter">
#  <div class="thmbgroup"><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">January 1, 2020<br/>Icaria Fossae7</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 31, 2020<br/>Proctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">December 31, 2020<br/>Icaria Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 29, 2020<br/>Proctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 28, 2020<br/>roctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">December 22, 2020<br/>Icaria Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/><p class="thumbcontent">December 21, 2020<br/>Icaria Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">December 18, 2020<br/>Ariadnes Colles</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">December 17, 2020<br/>Niger Vallis</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes.jpg"/><p class="thumbcontent">December 16, 2020<br/>Proctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">December 15, 2020<br/>Niger Vallis</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">December 11, 2020<br/>Daedalia Planum</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Sirenum Fossae.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Sirenum Fossae.jpg"/><p class="thumbcontent">November,11, 2020<br/>Sirenum Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">November,13, 2020<br/>Ariadnes Colles</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/South Polar Cap.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/><p class="thumbcontent">November,14, 2020<br/>South Polar Cap</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg"><div class="thmb"><img alt="" class="thumbimg" src="i ...
#  </div>,
#  <div class="thmbgroup"><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">January 1, 2020<br/>Icaria Fossae7</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 31, 2020<br/>Proctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">December 31, 2020<br/>Icaria Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 29, 2020<br/>Proctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 28, 2020<br/>roctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">December 22, 2020<br/>Icaria Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/><p class="thumbcontent">December 21, 2020<br/>Icaria Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">December 18, 2020<br/>Ariadnes Colles</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">December 17, 2020<br/>Niger Vallis</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes.jpg"/><p class="thumbcontent">December 16, 2020<br/>Proctor Crater Dunes</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">December 15, 2020<br/>Niger Vallis</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">December 11, 2020<br/>Daedalia Planum</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Sirenum Fossae.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Sirenum Fossae.jpg"/><p class="thumbcontent">November,11, 2020<br/>Sirenum Fossae</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">November,13, 2020<br/>Ariadnes Colles</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/South Polar Cap.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/><p class="thumbcontent">November,14, 2020<br/>South Polar Cap</p></div></a><a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg"><div class="thmb"><img alt="" class="thumbimg" src="i ...
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">January 1, 2020<br/>Icaria Fossae7</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">January 1, 2020<br/>Icaria Fossae7</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Icaria Fossae7</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 31, 2020<br/>Proctor Crater Dunes</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 31, 2020<br/>Proctor Crater Dunes</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/>,
#  <p class="thumbcontent">December 31, 2020<br/>Proctor Crater Dunes</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">December 31, 2020<br/>Icaria Fossae</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">December 31, 2020<br/>Icaria Fossae</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/>,
#  <p class="thumbcontent">December 31, 2020<br/>Icaria Fossae</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 29, 2020<br/>Proctor Crater Dunes</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 29, 2020<br/>Proctor Crater Dunes</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/>,
#  <p class="thumbcontent">December 29, 2020<br/>Proctor Crater Dunes</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes 7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 28, 2020<br/>roctor Crater Dunes</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/><p class="thumbcontent">December 28, 2020<br/>roctor Crater Dunes</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes 7.jpg"/>,
#  <p class="thumbcontent">December 28, 2020<br/>roctor Crater Dunes</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae7.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">December 22, 2020<br/>Icaria Fossae</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/><p class="thumbcontent">December 22, 2020<br/>Icaria Fossae</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Icaria Fossae7.jpg"/>,
#  <p class="thumbcontent">December 22, 2020<br/>Icaria Fossae</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/><p class="thumbcontent">December 21, 2020<br/>Icaria Fossae</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/><p class="thumbcontent">December 21, 2020<br/>Icaria Fossae</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/>,
#  <p class="thumbcontent">December 21, 2020<br/>Icaria Fossae</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">December 18, 2020<br/>Ariadnes Colles</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">December 18, 2020<br/>Ariadnes Colles</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/>,
#  <p class="thumbcontent">December 18, 2020<br/>Ariadnes Colles</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">December 17, 2020<br/>Niger Vallis</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">December 17, 2020<br/>Niger Vallis</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/>,
#  <p class="thumbcontent">December 17, 2020<br/>Niger Vallis</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes.jpg"/><p class="thumbcontent">December 16, 2020<br/>Proctor Crater Dunes</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes.jpg"/><p class="thumbcontent">December 16, 2020<br/>Proctor Crater Dunes</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes.jpg"/>,
#  <p class="thumbcontent">December 16, 2020<br/>Proctor Crater Dunes</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">December 15, 2020<br/>Niger Vallis</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">December 15, 2020<br/>Niger Vallis</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/>,
#  <p class="thumbcontent">December 15, 2020<br/>Niger Vallis</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">December 11, 2020<br/>Daedalia Planum</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">December 11, 2020<br/>Daedalia Planum</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/>,
#  <p class="thumbcontent">December 11, 2020<br/>Daedalia Planum</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Sirenum Fossae.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Sirenum Fossae.jpg"/><p class="thumbcontent">November,11, 2020<br/>Sirenum Fossae</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Sirenum Fossae.jpg"/><p class="thumbcontent">November,11, 2020<br/>Sirenum Fossae</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Sirenum Fossae.jpg"/>,
#  <p class="thumbcontent">November,11, 2020<br/>Sirenum Fossae</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">November,13, 2020<br/>Ariadnes Colles</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">November,13, 2020<br/>Ariadnes Colles</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/>,
#  <p class="thumbcontent">November,13, 2020<br/>Ariadnes Colles</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/South Polar Cap.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/><p class="thumbcontent">November,14, 2020<br/>South Polar Cap</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/><p class="thumbcontent">November,14, 2020<br/>South Polar Cap</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/>,
#  <p class="thumbcontent">November,14, 2020<br/>South Polar Cap</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">November,17, 2020<br/>Daedalia Planum</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">November,17, 2020<br/>Daedalia Planum</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/>,
#  <p class="thumbcontent">November,17, 2020<br/>Daedalia Planum</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles3.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles3.jpg"/><p class="thumbcontent">November,11, 2020<br/>Ariadnes Colles</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles3.jpg"/><p class="thumbcontent">November,11, 2020<br/>Ariadnes Colles</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Ariadnes Colles3.jpg"/>,
#  <p class="thumbcontent">November,11, 2020<br/>Ariadnes Colles</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Atlantis Chaos.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Atlantis Chaos.jpg"/><p class="thumbcontent">November,09, 2020<br/>Atlantis Chaos</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Atlantis Chaos.jpg"/><p class="thumbcontent">November,09, 2020<br/>Atlantis Chaos</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Atlantis Chaos.jpg"/>,
#  <p class="thumbcontent">November,09, 2020<br/>Atlantis Chaos</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">January 1, 2020<br/>Daedalia Planum</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">January 1, 2020<br/>Daedalia Planum</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Daedalia Planum</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/><p class="thumbcontent">January 1, 2020<br/>Icaria Fossae</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/><p class="thumbcontent">January 1, 2020<br/>Icaria Fossae</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Icaria Fossae</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">January 1, 2020<br/>Niger Vallis</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">January 1, 2020<br/>Niger Vallis</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Niger Vallis</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Proctor Crater Dunes.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes.jpg"/><p class="thumbcontent">January 1, 2020<br/>Proctor Crater Dunes</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes.jpg"/><p class="thumbcontent">January 1, 2020<br/>Proctor Crater Dunes</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Proctor Crater Dunes.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Proctor Crater Dunes</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Reull Vallis.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Reull Vallis.jpg"/><p class="thumbcontent">January 1, 2020<br/>Reull Vallis</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Reull Vallis.jpg"/><p class="thumbcontent">January 1, 2020<br/>Reull Vallis</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Reull Vallis.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Reull Vallis</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles3.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles3.jpg"/><p class="thumbcontent">January 1, 2020<br/>Ariadnes Colles</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles3.jpg"/><p class="thumbcontent">January 1, 2020<br/>Ariadnes Colles</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Ariadnes Colles3.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Ariadnes Colles</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Sirenum Fossae.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Sirenum Fossae.jpg"/><p class="thumbcontent">January 1, 2020<br/>Sirenum Fossae</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Sirenum Fossae.jpg"/><p class="thumbcontent">January 1, 2020<br/>Sirenum Fossae</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Sirenum Fossae.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Sirenum Fossae</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/South Polar Cap.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/><p class="thumbcontent">January 1, 2020<br/>South Polar Cap</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/><p class="thumbcontent">January 1, 2020<br/>South Polar Cap</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>South Polar Cap</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Niger Vallis.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">January 1, 2020<br/>Niger Vallis</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/><p class="thumbcontent">January 1, 2020<br/>Niger Vallis</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Niger Vallis.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Niger Vallis</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">January 1, 2020<br/>Daedalia Planum</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">January 1, 2020<br/>Daedalia Planum</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Daedalia Planum</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Icaria Fossae.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/><p class="thumbcontent">January 1, 2020<br/>Icaria Fossae</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/><p class="thumbcontent">January 1, 2020<br/>Icaria Fossae</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Icaria Fossae.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Icaria Fossae</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Ariadnes Colles4.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">January 1, 2020<br/>Ariadnes Colles</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/><p class="thumbcontent">January 1, 2020<br/>Ariadnes Colles</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Ariadnes Colles4.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Ariadnes Colles</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/South Polar Cap.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/><p class="thumbcontent">January 1, 2020<br/>South Polar Cap</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/><p class="thumbcontent">January 1, 2020<br/>South Polar Cap</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/South Polar Cap.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>South Polar Cap</p>,
#  <br/>,
#  <a class="fancybox-thumbs" data-fancybox-group="thumb" href="image/mars/Daedalia Planum.jpg"><div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">January 1, 2020<br/>Daedalia Planum</p></div></a>,
#  <div class="thmb"><img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/><p class="thumbcontent">January 1, 2020<br/>Daedalia Planum</p></div>,
#  <img alt="" class="thumbimg" src="image/mars/Daedalia Planum.jpg"/>,
#  <p class="thumbcontent">January 1, 2020<br/>Daedalia Planum</p>,
#  <br/>,
#  <div class="col-md-12 grid-margin" id="column">
#  <ul class="post-list">
#  <li class="post-heading"></li>
#  </ul>
#  </div>,
#  <ul class="post-list">
#  <li class="post-heading"></li>
#  </ul>,
#  <li class="post-heading"></li>,
#  <div class="first imgcontainer mt-3">
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-3">
#  <img id="pic" src=""/>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-3">
#  <img id="pic" src=""/>
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-3">
#  <img id="pic" src=""/>
#  </div>
#  </div>,
#  <div class="col-md-3">
#  <img id="pic" src=""/>
#  </div>,
#  <img id="pic" src=""/>,
#  <div class="module_gallery container">
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-6">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/jpl_photojournal(3x1).jpg"/>
#  <div class="card-body">
#  <h5 class="card-title">JPL Photojournal</h5>
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-6">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/nasa_images(3x1).jpg"/>
#  <div class="card-body">
#  <h5 class="card-title">Great images in NASA</h5>
#  <p class="card-text">A selection of the best-known images from a half-century of exploration and discovery</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-6">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/jpl_photojournal(3x1).jpg"/>
#  <div class="card-body">
#  <h5 class="card-title">JPL Photojournal</h5>
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-6">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/nasa_images(3x1).jpg"/>
#  <div class="card-body">
#  <h5 class="card-title">Great images in NASA</h5>
#  <p class="card-text">A selection of the best-known images from a half-century of exploration and discovery</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-6">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/jpl_photojournal(3x1).jpg"/>
#  <div class="card-body">
#  <h5 class="card-title">JPL Photojournal</h5>
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-6">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/nasa_images(3x1).jpg"/>
#  <div class="card-body">
#  <h5 class="card-title">Great images in NASA</h5>
#  <p class="card-text">A selection of the best-known images from a half-century of exploration and discovery</p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-6">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/jpl_photojournal(3x1).jpg"/>
#  <div class="card-body">
#  <h5 class="card-title">JPL Photojournal</h5>
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/jpl_photojournal(3x1).jpg"/>
#  <div class="card-body">
#  <h5 class="card-title">JPL Photojournal</h5>
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>,
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/jpl_photojournal(3x1).jpg"/>,
#  <div class="card-body">
#  <h5 class="card-title">JPL Photojournal</h5>
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>,
#  <h5 class="card-title">JPL Photojournal</h5>,
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>,
#  <div class="col-md-6">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/nasa_images(3x1).jpg"/>
#  <div class="card-body">
#  <h5 class="card-title">Great images in NASA</h5>
#  <p class="card-text">A selection of the best-known images from a half-century of exploration and discovery</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/nasa_images(3x1).jpg"/>
#  <div class="card-body">
#  <h5 class="card-title">Great images in NASA</h5>
#  <p class="card-text">A selection of the best-known images from a half-century of exploration and discovery</p>
#  </div>
#  </div>,
#  <img alt="Card image cap" class="card-img-top" src="https://www.jpl.nasa.gov/assets/images/content/tmp/images/nasa_images(3x1).jpg"/>,
#  <div class="card-body">
#  <h5 class="card-title">Great images in NASA</h5>
#  <p class="card-text">A selection of the best-known images from a half-century of exploration and discovery</p>
#  </div>,
#  <h5 class="card-title">Great images in NASA</h5>,
#  <p class="card-text">A selection of the best-known images from a half-century of exploration and discovery</p>,
#  <div class="multi_teaser">
#  <div class="container">
#  <h1>You Might Also Like</h1>
#  <div class="col-md-12 mt-5">
#  <div class="row">
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA24304---CatScanMars-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/PIA23491-16-640x350.jpg"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA23180-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="container">
#  <h1>You Might Also Like</h1>
#  <div class="col-md-12 mt-5">
#  <div class="row">
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA24304---CatScanMars-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/PIA23491-16-640x350.jpg"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA23180-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <h1>You Might Also Like</h1>,
#  <div class="col-md-12 mt-5">
#  <div class="row">
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA24304---CatScanMars-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/PIA23491-16-640x350.jpg"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA23180-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA24304---CatScanMars-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/PIA23491-16-640x350.jpg"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA23180-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA24304---CatScanMars-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA24304---CatScanMars-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>,
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA24304---CatScanMars-16-640x350.gif"/>,
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>,
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>,
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/PIA23491-16-640x350.jpg"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/PIA23491-16-640x350.jpg"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>,
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/PIA23491-16-640x350.jpg"/>,
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>,
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>,
#  <div class="col-md-4">
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA23180-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>
#  </div>,
#  <div class="card">
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA23180-16-640x350.gif"/>
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>
#  </div>,
#  <img alt="Card image cap" class="card-img-top" src="https://imagecache.jpl.nasa.gov/images/640x350/C1-PIA23180-16-640x350.gif"/>,
#  <div class="card-body">
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>
#  </div>,
#  <p class="card-text">Access to the full library of publicly released images from various Solar System exploration programs</p>,
#  <div class="footer">
#  <div class="container">
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-3">
#  <h4>About JPL</h4>
#  <ul>
#  <li>About JPL</li>
#  <li>JPL Vision</li>
#  <li>Executive Council</li>
#  <li>History</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Education</h4>
#  <ul>
#  <li>Intern</li>
#  <li>Learn</li>
#  <li>Teach</li>
#  <li>News</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Our Sites</h4>
#  <ul>
#  <li>Asteroid Watch</li>
#  <li>Basics of Spaceflight</li>
#  <li>Cassini - Mission to Saturn</li>
#  <li>Climate Kids</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Galleries</h4>
#  <ul>
#  <li>JPL Space Images</li>
#  <li>Videos</li>
#  <li>Infographics</li>
#  <li>Photojournal</li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="container">
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-3">
#  <h4>About JPL</h4>
#  <ul>
#  <li>About JPL</li>
#  <li>JPL Vision</li>
#  <li>Executive Council</li>
#  <li>History</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Education</h4>
#  <ul>
#  <li>Intern</li>
#  <li>Learn</li>
#  <li>Teach</li>
#  <li>News</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Our Sites</h4>
#  <ul>
#  <li>Asteroid Watch</li>
#  <li>Basics of Spaceflight</li>
#  <li>Cassini - Mission to Saturn</li>
#  <li>Climate Kids</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Galleries</h4>
#  <ul>
#  <li>JPL Space Images</li>
#  <li>Videos</li>
#  <li>Infographics</li>
#  <li>Photojournal</li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="col-md-12">
#  <div class="row">
#  <div class="col-md-3">
#  <h4>About JPL</h4>
#  <ul>
#  <li>About JPL</li>
#  <li>JPL Vision</li>
#  <li>Executive Council</li>
#  <li>History</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Education</h4>
#  <ul>
#  <li>Intern</li>
#  <li>Learn</li>
#  <li>Teach</li>
#  <li>News</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Our Sites</h4>
#  <ul>
#  <li>Asteroid Watch</li>
#  <li>Basics of Spaceflight</li>
#  <li>Cassini - Mission to Saturn</li>
#  <li>Climate Kids</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Galleries</h4>
#  <ul>
#  <li>JPL Space Images</li>
#  <li>Videos</li>
#  <li>Infographics</li>
#  <li>Photojournal</li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-3">
#  <h4>About JPL</h4>
#  <ul>
#  <li>About JPL</li>
#  <li>JPL Vision</li>
#  <li>Executive Council</li>
#  <li>History</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Education</h4>
#  <ul>
#  <li>Intern</li>
#  <li>Learn</li>
#  <li>Teach</li>
#  <li>News</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Our Sites</h4>
#  <ul>
#  <li>Asteroid Watch</li>
#  <li>Basics of Spaceflight</li>
#  <li>Cassini - Mission to Saturn</li>
#  <li>Climate Kids</li>
#  </ul>
#  </div>
#  <div class="col-md-3">
#  <h4>Galleries</h4>
#  <ul>
#  <li>JPL Space Images</li>
#  <li>Videos</li>
#  <li>Infographics</li>
#  <li>Photojournal</li>
#  </ul>
#  </div>
#  </div>,
#  <div class="col-md-3">
#  <h4>About JPL</h4>
#  <ul>
#  <li>About JPL</li>
#  <li>JPL Vision</li>
#  <li>Executive Council</li>
#  <li>History</li>
#  </ul>
#  </div>,
#  <h4>About JPL</h4>,
#  <ul>
#  <li>About JPL</li>
#  <li>JPL Vision</li>
#  <li>Executive Council</li>
#  <li>History</li>
#  </ul>,
#  <li>About JPL</li>,
#  <li>JPL Vision</li>,
#  <li>Executive Council</li>,
#  <li>History</li>,
#  <div class="col-md-3">
#  <h4>Education</h4>
#  <ul>
#  <li>Intern</li>
#  <li>Learn</li>
#  <li>Teach</li>
#  <li>News</li>
#  </ul>
#  </div>,
#  <h4>Education</h4>,
#  <ul>
#  <li>Intern</li>
#  <li>Learn</li>
#  <li>Teach</li>
#  <li>News</li>
#  </ul>,
#  <li>Intern</li>,
#  <li>Learn</li>,
#  <li>Teach</li>,
#  <li>News</li>,
#  <div class="col-md-3">
#  <h4>Our Sites</h4>
#  <ul>
#  <li>Asteroid Watch</li>
#  <li>Basics of Spaceflight</li>
#  <li>Cassini - Mission to Saturn</li>
#  <li>Climate Kids</li>
#  </ul>
#  </div>,
#  <h4>Our Sites</h4>,
#  <ul>
#  <li>Asteroid Watch</li>
#  <li>Basics of Spaceflight</li>
#  <li>Cassini - Mission to Saturn</li>
#  <li>Climate Kids</li>
#  </ul>,
#  <li>Asteroid Watch</li>,
#  <li>Basics of Spaceflight</li>,
#  <li>Cassini - Mission to Saturn</li>,
#  <li>Climate Kids</li>,
#  <div class="col-md-3">
#  <h4>Galleries</h4>
#  <ul>
#  <li>JPL Space Images</li>
#  <li>Videos</li>
#  <li>Infographics</li>
#  <li>Photojournal</li>
#  </ul>
#  </div>,
#  <h4>Galleries</h4>,
#  <ul>
#  <li>JPL Space Images</li>
#  <li>Videos</li>
#  <li>Infographics</li>
#  <li>Photojournal</li>
#  </ul>,
#  <li>JPL Space Images</li>,
#  <li>Videos</li>,
#  <li>Infographics</li>,
#  <li>Photojournal</li>,
#  <script src="js/jquery-3.5.1.min.js"></script>,
#  <script src="js/demo.js"></script>,
#  <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.12.9/umd/popper.min.js"></script>,
#  <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"></script>,
#  <script src="js/fancyBox/jquery.fancybox.pack.js?v=2.1.5" type="text/javascript"></script>,
#  <link href="js/fancyBox/jquery.fancybox.css?v=2.1.5" media="screen" rel="stylesheet" type="text/css"/>,
#  <link href="js/fancyBox/helpers/jquery.fancybox-thumbs.css?v=1.0.7" rel="stylesheet" type="text/css"/>,
#  <script src="js/fancyBox/helpers/jquery.fancybox-thumbs.js?v=1.0.7" type="text/javascript"></script>]

# %%
# Get featured image url
f_mars_img = soup.find('img', {'class': ['headerimage','fade-in']})['src']
mars_img_url = f'{url}{f_mars_img}'
mars_img_url
# Out:
# 'https://redplanetscience.com/#image/featured/mars2.jpg'

# %%
##############################
# Mars Facts
##############################

# %%
# Get Mars Facts URL
url3 = "https://galaxyfacts-mars.com/"

# %%
# Read Mars Stats Table with Pandas
mars_stats = pd.read_html(url3)
mars_stats
# Out:
# [                         0                1                2
#  0  Mars - Earth Comparison             Mars            Earth
#  1                Diameter:         6,779 km        12,742 km
#  2                    Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
#  3                   Moons:                2                1
#  4       Distance from Sun:   227,943,824 km   149,598,262 km
#  5          Length of Year:   687 Earth days      365.24 days
#  6             Temperature:     -87 to -5 °C      -88 to 58°C,
#                        0                              1
#  0  Equatorial Diameter:                       6,792 km
#  1       Polar Diameter:                       6,752 km
#  2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
#  3                Moons:          2 ( Phobos & Deimos )
#  4       Orbit Distance:       227,943,824 km (1.38 AU)
#  5         Orbit Period:           687 days (1.9 years)
#  6  Surface Temperature:                   -87 to -5 °C
#  7         First Record:              2nd millennium BC
#  8          Recorded By:           Egyptian astronomers]

# %%
# Create df 
mars_df = mars_stats[0]
mars_df
# Out:
#                          0                1                2
# 0  Mars - Earth Comparison             Mars            Earth
# 1                Diameter:         6,779 km        12,742 km
# 2                    Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 3                   Moons:                2                1
# 4       Distance from Sun:   227,943,824 km   149,598,262 km
# 5          Length of Year:   687 Earth days      365.24 days
# 6             Temperature:     -87 to -5 °C      -88 to 58°C

# %%
# Cleaning df
# Make first row the table headers
header = mars_df.iloc[0]
mars_df = mars_df[1:]
mars_df.columns = header
mars_df
# Out:
# 0 Mars - Earth Comparison             Mars            Earth
# 1               Diameter:         6,779 km        12,742 km
# 2                   Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 3                  Moons:                2                1
# 4      Distance from Sun:   227,943,824 km   149,598,262 km
# 5         Length of Year:   687 Earth days      365.24 days
# 6            Temperature:     -87 to -5 °C      -88 to 58°C

# %%
# Make 'Mars - Earth Comparison' column the index
mars_df.set_index('Mars - Earth Comparison', inplace=True)
mars_df
# Out:
# 0                                   Mars            Earth
# Mars - Earth Comparison
# Diameter:                       6,779 km        12,742 km
# Mass:                    6.39 × 10^23 kg  5.97 × 10^24 kg
# Moons:                                 2                1
# Distance from Sun:        227,943,824 km   149,598,262 km
# Length of Year:           687 Earth days      365.24 days
# Temperature:                -87 to -5 °C      -88 to 58°C

# %%
# Convert mars_df to html table for use later
mars_df.to_html('mars_stats.html')

# %%
##############################
# Mars Hemispheres
##############################

# %%
# Mars Hemispheres URL
url4 = "https://marshemispheres.com/"

# %%
# Visit Mars Hemispheres page in browser, wait for all content to generate
browser.visit(url4)
time.sleep(3)
html4 = browser.html

# %%
# Create BS object and parse it
soup = BeautifulSoup(html4, "lxml")

# %%
# Check to see if page is correct
soup.body()
# Out:
# [<header>
#  <a href="#" style="float:right;margin-top:10px;" target="_blank">
#  <img alt="USGS: Science for a Changing World" class="logo" height="60" src="images/usgs_logo_main_2x.png"/>
#  </a>
#  <a href="#" style="float:right;margin-top:5px;margin-right:20px;" target="_blank">
#  <img alt="NASA" class="logo" height="65" src="images/nasa-logo-web-med.png"/>
#  </a>
#  </header>,
#  <a href="#" style="float:right;margin-top:10px;" target="_blank">
#  <img alt="USGS: Science for a Changing World" class="logo" height="60" src="images/usgs_logo_main_2x.png"/>
#  </a>,
#  <img alt="USGS: Science for a Changing World" class="logo" height="60" src="images/usgs_logo_main_2x.png"/>,
#  <a href="#" style="float:right;margin-top:5px;margin-right:20px;" target="_blank">
#  <img alt="NASA" class="logo" height="65" src="images/nasa-logo-web-med.png"/>
#  </a>,
#  <img alt="NASA" class="logo" height="65" src="images/nasa-logo-web-med.png"/>,
#  <div class="wrapper">
#  <div class="container">
#  <div class="widget block bar">
#  <a href="https://astrogeology.usgs.gov/search" style="float:right;text-decoration:none;">
#  <img alt="Astropedia" src="images/astropedia-logo-main.png" style="width:200px;border:none;float:right;"/>
#  <div style="clear:both;font-size:.8em;float:right;color:#888;">Lunar and Planetary Cartographic Catalog</div>
#  </a>
#  <div style="float:left;height:60px;">
#  </div>
#  </div>
#  <div class="full-content">
#  <section class="block" id="results-accordian">
#  <div class="result-list" data-section="product" id="product-section">
#  <div class="accordian">
#  <h2>Products</h2>
#  <span class="count">4 Results</span>
#  <span class="collapse">Collapse</span>
#  </div>
#  <div class="collapsible results">
#  <div class="item">
#  <a class="itemLink product-item" href="cerberus.html"><img alt="Cerberus Hemisphere Enhanced thumbnail" class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="cerberus.html">
#  <h3>Cerberus Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 21 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquired…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="schiaparelli.html"><img alt="Schiaparelli Hemisphere Enhanced thumbnail" class="thumb" src="images/08eac6e22c07fb1fe72223a79252de20_schiaparelli_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="schiaparelli.html">
#  <h3>Schiaparelli Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 35 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northern…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="syrtis.html"><img alt="Syrtis Major Hemisphere Enhanced thumbnail" class="thumb" src="images/55a0a1e2796313fdeafb17c35925e8ac_syrtis_major_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="syrtis.html">
#  <h3>Syrtis Major Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 25 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violet…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="valles.html"><img alt="Valles Marineris Hemisphere Enhanced thumbnail" class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="valles.html">
#  <h3>Valles Marineris Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 27 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  </div>
#  <!-- end this-section -->
#  </div>
#  </section>
#  </div>
#  <div class="navigation clear" style="display: none;">
#  <a class="itemLink product-item" href="#" onclick="showMain()">
#  <h3>Back</h3>
#  </a>
#  </div>
#  </div>
#  <footer>
#  <div class="left">
#  <a href="#">Search</a> |
#                 <a href="#">About</a> |
#                 <a href="#">Contact</a>
#  </div>
#  <div class="right">
#  <a href="#">GUSS Science Center</a>
#  </div>
#  </footer>
#  </div>,
#  <div class="container">
#  <div class="widget block bar">
#  <a href="https://astrogeology.usgs.gov/search" style="float:right;text-decoration:none;">
#  <img alt="Astropedia" src="images/astropedia-logo-main.png" style="width:200px;border:none;float:right;"/>
#  <div style="clear:both;font-size:.8em;float:right;color:#888;">Lunar and Planetary Cartographic Catalog</div>
#  </a>
#  <div style="float:left;height:60px;">
#  </div>
#  </div>
#  <div class="full-content">
#  <section class="block" id="results-accordian">
#  <div class="result-list" data-section="product" id="product-section">
#  <div class="accordian">
#  <h2>Products</h2>
#  <span class="count">4 Results</span>
#  <span class="collapse">Collapse</span>
#  </div>
#  <div class="collapsible results">
#  <div class="item">
#  <a class="itemLink product-item" href="cerberus.html"><img alt="Cerberus Hemisphere Enhanced thumbnail" class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="cerberus.html">
#  <h3>Cerberus Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 21 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquired…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="schiaparelli.html"><img alt="Schiaparelli Hemisphere Enhanced thumbnail" class="thumb" src="images/08eac6e22c07fb1fe72223a79252de20_schiaparelli_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="schiaparelli.html">
#  <h3>Schiaparelli Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 35 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northern…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="syrtis.html"><img alt="Syrtis Major Hemisphere Enhanced thumbnail" class="thumb" src="images/55a0a1e2796313fdeafb17c35925e8ac_syrtis_major_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="syrtis.html">
#  <h3>Syrtis Major Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 25 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violet…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="valles.html"><img alt="Valles Marineris Hemisphere Enhanced thumbnail" class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="valles.html">
#  <h3>Valles Marineris Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 27 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  </div>
#  <!-- end this-section -->
#  </div>
#  </section>
#  </div>
#  <div class="navigation clear" style="display: none;">
#  <a class="itemLink product-item" href="#" onclick="showMain()">
#  <h3>Back</h3>
#  </a>
#  </div>
#  </div>,
#  <div class="widget block bar">
#  <a href="https://astrogeology.usgs.gov/search" style="float:right;text-decoration:none;">
#  <img alt="Astropedia" src="images/astropedia-logo-main.png" style="width:200px;border:none;float:right;"/>
#  <div style="clear:both;font-size:.8em;float:right;color:#888;">Lunar and Planetary Cartographic Catalog</div>
#  </a>
#  <div style="float:left;height:60px;">
#  </div>
#  </div>,
#  <a href="https://astrogeology.usgs.gov/search" style="float:right;text-decoration:none;">
#  <img alt="Astropedia" src="images/astropedia-logo-main.png" style="width:200px;border:none;float:right;"/>
#  <div style="clear:both;font-size:.8em;float:right;color:#888;">Lunar and Planetary Cartographic Catalog</div>
#  </a>,
#  <img alt="Astropedia" src="images/astropedia-logo-main.png" style="width:200px;border:none;float:right;"/>,
#  <div style="clear:both;font-size:.8em;float:right;color:#888;">Lunar and Planetary Cartographic Catalog</div>,
#  <div style="float:left;height:60px;">
#  </div>,
#  <div class="full-content">
#  <section class="block" id="results-accordian">
#  <div class="result-list" data-section="product" id="product-section">
#  <div class="accordian">
#  <h2>Products</h2>
#  <span class="count">4 Results</span>
#  <span class="collapse">Collapse</span>
#  </div>
#  <div class="collapsible results">
#  <div class="item">
#  <a class="itemLink product-item" href="cerberus.html"><img alt="Cerberus Hemisphere Enhanced thumbnail" class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="cerberus.html">
#  <h3>Cerberus Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 21 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquired…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="schiaparelli.html"><img alt="Schiaparelli Hemisphere Enhanced thumbnail" class="thumb" src="images/08eac6e22c07fb1fe72223a79252de20_schiaparelli_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="schiaparelli.html">
#  <h3>Schiaparelli Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 35 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northern…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="syrtis.html"><img alt="Syrtis Major Hemisphere Enhanced thumbnail" class="thumb" src="images/55a0a1e2796313fdeafb17c35925e8ac_syrtis_major_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="syrtis.html">
#  <h3>Syrtis Major Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 25 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violet…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="valles.html"><img alt="Valles Marineris Hemisphere Enhanced thumbnail" class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="valles.html">
#  <h3>Valles Marineris Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 27 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  </div>
#  <!-- end this-section -->
#  </div>
#  </section>
#  </div>,
#  <section class="block" id="results-accordian">
#  <div class="result-list" data-section="product" id="product-section">
#  <div class="accordian">
#  <h2>Products</h2>
#  <span class="count">4 Results</span>
#  <span class="collapse">Collapse</span>
#  </div>
#  <div class="collapsible results">
#  <div class="item">
#  <a class="itemLink product-item" href="cerberus.html"><img alt="Cerberus Hemisphere Enhanced thumbnail" class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="cerberus.html">
#  <h3>Cerberus Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 21 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquired…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="schiaparelli.html"><img alt="Schiaparelli Hemisphere Enhanced thumbnail" class="thumb" src="images/08eac6e22c07fb1fe72223a79252de20_schiaparelli_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="schiaparelli.html">
#  <h3>Schiaparelli Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 35 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northern…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="syrtis.html"><img alt="Syrtis Major Hemisphere Enhanced thumbnail" class="thumb" src="images/55a0a1e2796313fdeafb17c35925e8ac_syrtis_major_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="syrtis.html">
#  <h3>Syrtis Major Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 25 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violet…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="valles.html"><img alt="Valles Marineris Hemisphere Enhanced thumbnail" class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="valles.html">
#  <h3>Valles Marineris Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 27 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  </div>
#  <!-- end this-section -->
#  </div>
#  </section>,
#  <div class="result-list" data-section="product" id="product-section">
#  <div class="accordian">
#  <h2>Products</h2>
#  <span class="count">4 Results</span>
#  <span class="collapse">Collapse</span>
#  </div>
#  <div class="collapsible results">
#  <div class="item">
#  <a class="itemLink product-item" href="cerberus.html"><img alt="Cerberus Hemisphere Enhanced thumbnail" class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="cerberus.html">
#  <h3>Cerberus Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 21 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquired…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="schiaparelli.html"><img alt="Schiaparelli Hemisphere Enhanced thumbnail" class="thumb" src="images/08eac6e22c07fb1fe72223a79252de20_schiaparelli_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="schiaparelli.html">
#  <h3>Schiaparelli Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 35 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northern…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="syrtis.html"><img alt="Syrtis Major Hemisphere Enhanced thumbnail" class="thumb" src="images/55a0a1e2796313fdeafb17c35925e8ac_syrtis_major_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="syrtis.html">
#  <h3>Syrtis Major Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 25 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violet…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="valles.html"><img alt="Valles Marineris Hemisphere Enhanced thumbnail" class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="valles.html">
#  <h3>Valles Marineris Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 27 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  </div>
#  <!-- end this-section -->
#  </div>,
#  <div class="accordian">
#  <h2>Products</h2>
#  <span class="count">4 Results</span>
#  <span class="collapse">Collapse</span>
#  </div>,
#  <h2>Products</h2>,
#  <span class="count">4 Results</span>,
#  <span class="collapse">Collapse</span>,
#  <div class="collapsible results">
#  <div class="item">
#  <a class="itemLink product-item" href="cerberus.html"><img alt="Cerberus Hemisphere Enhanced thumbnail" class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="cerberus.html">
#  <h3>Cerberus Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 21 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquired…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="schiaparelli.html"><img alt="Schiaparelli Hemisphere Enhanced thumbnail" class="thumb" src="images/08eac6e22c07fb1fe72223a79252de20_schiaparelli_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="schiaparelli.html">
#  <h3>Schiaparelli Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 35 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northern…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="syrtis.html"><img alt="Syrtis Major Hemisphere Enhanced thumbnail" class="thumb" src="images/55a0a1e2796313fdeafb17c35925e8ac_syrtis_major_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="syrtis.html">
#  <h3>Syrtis Major Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 25 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violet…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  <div class="item">
#  <a class="itemLink product-item" href="valles.html"><img alt="Valles Marineris Hemisphere Enhanced thumbnail" class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="valles.html">
#  <h3>Valles Marineris Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 27 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of…</p>
#  </div>
#  <!-- end description -->
#  </div>
#  </div>,
#  <div class="item">
#  <a class="itemLink product-item" href="cerberus.html"><img alt="Cerberus Hemisphere Enhanced thumbnail" class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="cerberus.html">
#  <h3>Cerberus Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 21 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquired…</p>
#  </div>
#  <!-- end description -->
#  </div>,
#  <a class="itemLink product-item" href="cerberus.html"><img alt="Cerberus Hemisphere Enhanced thumbnail" class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png"/></a>,
#  <img alt="Cerberus Hemisphere Enhanced thumbnail" class="thumb" src="images/39d3266553462198bd2fbc4d18fbed17_cerberus_enhanced.tif_thumb.png"/>,
#  <div class="description">
#  <a class="itemLink product-item" href="cerberus.html">
#  <h3>Cerberus Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 21 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquired…</p>
#  </div>,
#  <a class="itemLink product-item" href="cerberus.html">
#  <h3>Cerberus Hemisphere Enhanced</h3>
#  </a>,
#  <h3>Cerberus Hemisphere Enhanced</h3>,
#  <span class="subtitle" style="float:left">image/tiff 21 MB</span>,
#  <span class="pubDate" style="float:right"></span>,
#  <br/>,
#  <p>Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquired…</p>,
#  <div class="item">
#  <a class="itemLink product-item" href="schiaparelli.html"><img alt="Schiaparelli Hemisphere Enhanced thumbnail" class="thumb" src="images/08eac6e22c07fb1fe72223a79252de20_schiaparelli_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="schiaparelli.html">
#  <h3>Schiaparelli Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 35 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northern…</p>
#  </div>
#  <!-- end description -->
#  </div>,
#  <a class="itemLink product-item" href="schiaparelli.html"><img alt="Schiaparelli Hemisphere Enhanced thumbnail" class="thumb" src="images/08eac6e22c07fb1fe72223a79252de20_schiaparelli_enhanced.tif_thumb.png"/></a>,
#  <img alt="Schiaparelli Hemisphere Enhanced thumbnail" class="thumb" src="images/08eac6e22c07fb1fe72223a79252de20_schiaparelli_enhanced.tif_thumb.png"/>,
#  <div class="description">
#  <a class="itemLink product-item" href="schiaparelli.html">
#  <h3>Schiaparelli Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 35 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northern…</p>
#  </div>,
#  <a class="itemLink product-item" href="schiaparelli.html">
#  <h3>Schiaparelli Hemisphere Enhanced</h3>
#  </a>,
#  <h3>Schiaparelli Hemisphere Enhanced</h3>,
#  <span class="subtitle" style="float:left">image/tiff 35 MB</span>,
#  <span class="pubDate" style="float:right"></span>,
#  <br/>,
#  <p>Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northern…</p>,
#  <div class="item">
#  <a class="itemLink product-item" href="syrtis.html"><img alt="Syrtis Major Hemisphere Enhanced thumbnail" class="thumb" src="images/55a0a1e2796313fdeafb17c35925e8ac_syrtis_major_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="syrtis.html">
#  <h3>Syrtis Major Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 25 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violet…</p>
#  </div>
#  <!-- end description -->
#  </div>,
#  <a class="itemLink product-item" href="syrtis.html"><img alt="Syrtis Major Hemisphere Enhanced thumbnail" class="thumb" src="images/55a0a1e2796313fdeafb17c35925e8ac_syrtis_major_enhanced.tif_thumb.png"/></a>,
#  <img alt="Syrtis Major Hemisphere Enhanced thumbnail" class="thumb" src="images/55a0a1e2796313fdeafb17c35925e8ac_syrtis_major_enhanced.tif_thumb.png"/>,
#  <div class="description">
#  <a class="itemLink product-item" href="syrtis.html">
#  <h3>Syrtis Major Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 25 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violet…</p>
#  </div>,
#  <a class="itemLink product-item" href="syrtis.html">
#  <h3>Syrtis Major Hemisphere Enhanced</h3>
#  </a>,
#  <h3>Syrtis Major Hemisphere Enhanced</h3>,
#  <span class="subtitle" style="float:left">image/tiff 25 MB</span>,
#  <span class="pubDate" style="float:right"></span>,
#  <br/>,
#  <p>Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violet…</p>,
#  <div class="item">
#  <a class="itemLink product-item" href="valles.html"><img alt="Valles Marineris Hemisphere Enhanced thumbnail" class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/></a>
#  <div class="description">
#  <a class="itemLink product-item" href="valles.html">
#  <h3>Valles Marineris Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 27 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of…</p>
#  </div>
#  <!-- end description -->
#  </div>,
#  <a class="itemLink product-item" href="valles.html"><img alt="Valles Marineris Hemisphere Enhanced thumbnail" class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/></a>,
#  <img alt="Valles Marineris Hemisphere Enhanced thumbnail" class="thumb" src="images/4e59980c1c57f89c680c0e1ccabbeff1_valles_marineris_enhanced.tif_thumb.png"/>,
#  <div class="description">
#  <a class="itemLink product-item" href="valles.html">
#  <h3>Valles Marineris Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 27 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of…</p>
#  </div>,
#  <a class="itemLink product-item" href="valles.html">
#  <h3>Valles Marineris Hemisphere Enhanced</h3>
#  </a>,
#  <h3>Valles Marineris Hemisphere Enhanced</h3>,
#  <span class="subtitle" style="float:left">image/tiff 27 MB</span>,
#  <span class="pubDate" style="float:right"></span>,
#  <br/>,
#  <p>Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of…</p>,
#  <div class="navigation clear" style="display: none;">
#  <a class="itemLink product-item" href="#" onclick="showMain()">
#  <h3>Back</h3>
#  </a>
#  </div>,
#  <a class="itemLink product-item" href="#" onclick="showMain()">
#  <h3>Back</h3>
#  </a>,
#  <h3>Back</h3>,
#  <footer>
#  <div class="left">
#  <a href="#">Search</a> |
#                 <a href="#">About</a> |
#                 <a href="#">Contact</a>
#  </div>
#  <div class="right">
#  <a href="#">GUSS Science Center</a>
#  </div>
#  </footer>,
#  <div class="left">
#  <a href="#">Search</a> |
#                 <a href="#">About</a> |
#                 <a href="#">Contact</a>
#  </div>,
#  <a href="#">Search</a>,
#  <a href="#">About</a>,
#  <a href="#">Contact</a>,
#  <div class="right">
#  <a href="#">GUSS Science Center</a>
#  </div>,
#  <a href="#">GUSS Science Center</a>,
#  <div class="page-background" style="
#           background:url('./images/mars.jpg');
#           filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(
#           src='./images/mars.jpg', sizingMethod='scale');
#           "></div>,
#  <script type="text/javascript">
#           var baseUrl = "";
#
#
#
#        </script>,
#  <script src="js/jquery.min.js" type="text/javascript"></script>,
#  <script src="js/jquery-ui.min.js" type="text/javascript"></script>,
#  <script src="js/general.js" type="text/javascript"></script>]

# %%
# Get div class description, which holds the links for the hemisphere pages
results2 = soup.find_all('div', class_='description')
results2
# Out:
# [<div class="description">
#  <a class="itemLink product-item" href="cerberus.html">
#  <h3>Cerberus Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 21 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Cerberus hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of 104 Viking Orbiter images acquired…</p>
#  </div>,
#  <div class="description">
#  <a class="itemLink product-item" href="schiaparelli.html">
#  <h3>Schiaparelli Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 35 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Schiaparelli hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The images were acquired in 1980 during early northern…</p>
#  </div>,
#  <div class="description">
#  <a class="itemLink product-item" href="syrtis.html">
#  <h3>Syrtis Major Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 25 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Syrtis Major hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. This mosaic is composed of about 100 red and violet…</p>
#  </div>,
#  <div class="description">
#  <a class="itemLink product-item" href="valles.html">
#  <h3>Valles Marineris Hemisphere Enhanced</h3>
#  </a>
#  <span class="subtitle" style="float:left">image/tiff 27 MB</span><span class="pubDate" style="float:right"></span><br/>
#  <p>Mosaic of the Valles Marineris hemisphere of Mars projected into point perspective, a view similar to that which one would see from a spacecraft. The distance is 2500 kilometers from the surface of…</p>
#  </div>]

# %%
# Create empty array to hold image urls
hemisphere_imgs = []

# %%
for result in results2:
    
    # Find link to hemisphere page
    hem_page = result.find('a', class_='itemLink')['href']
    hem_page = f'{url4}{hem_page}'
    
    # Open hemisphere page in bs
    hem_response = requests.get(hem_page)
    soup2 = BeautifulSoup(hem_response.text, 'lxml')
    
    # Find and retrieve image url of hemisphere
    # Get the original .tif image, which is the second in the list (position 1)
    # Then, extract the link to the image
    hem_img_u = soup2.find_all('li')[0]
    hem_img = hem_img_u.find('a')['href']
    hem_img = f'{url4}{hem_img}'
    
    # Append hemisphere image link to hemisphere_imgs array
    hemisphere_imgs.append(hem_img)

# %%
hemisphere_imgs
# Out:
# ['https://marshemispheres.com/images/full.jpg',
#  'https://marshemispheres.com/images/schiaparelli_enhanced-full.jpg',
#  'https://marshemispheres.com/images/syrtis_major_enhanced-full.jpg',
#  'https://marshemispheres.com/images/valles_marineris_enhanced-full.jpg']

# %%
# Create dictionary 
hemisphere_image_urls = [
    {"title": "Cerberus", "img_url": hemisphere_imgs[0]},
    {"title": "Schiaparelli", "img_url": hemisphere_imgs[1]},
    {"title": "Syrtis Major", "img_url": hemisphere_imgs[2]},
    {"title": "Valles Marineris", "img_url": hemisphere_imgs[3]}
]
hemisphere_image_urls
# Out:
# [{'title': 'Cerberus',
#   'img_url': 'https://marshemispheres.com/images/cerberus_enhanced.tif'},
#  {'title': 'Schiaparelli',
#   'img_url': 'https://marshemispheres.com/images/schiaparelli_enhanced.tif'},
#  {'title': 'Syrtis Major',
#   'img_url': 'https://marshemispheres.com/images/syrtis_major_enhanced.tif'},
#  {'title': 'Valles Marineris',
#   'img_url': 'https://marshemispheres.com/images/valles_marineris_enhanced.tif'}]

# %%
browser.quit()
